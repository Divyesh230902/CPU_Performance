# %% [markdown]
# # PBL Review 2
#
# ![Hardware Photo](asset/pexels-pixabay-159235.jpg)
#
# ## Team:
# > - Mahir Patel
# > - Divyesh Patel
# > - Diya Patel
# > - Meet Motta
# > - Tushar Patel
#
# ## Abstract:
# > This is the Data of Hardware which is now a day a major concern for many people working, so to know the best hardware this is the **exploratory analysis** through which we are carrying out the insider's report on the hardware available out there.

# %%
import pandas as pd

# %% [markdown]
# ### Data Imported
# > **Note**: This Data is taken from https://www.kaggle.com/datasets/michaelbryantds/cpu-and-gpu-product-data for the purpose of analyis
#
# ### About Dataset
#
# A dataset with 2,185 CPUs and 2,668 GPUs to help researchers understand the development trend of CPUs and GPUs.
#
# Here are some interesting facts supported by the data:
# - Moore's Law still holds, especially in GPUs.
# - Dannard Scaling is still valid in general.
# - CPUs have higher frequencies, but GPUs are catching up.
# - GPU performance doubles every 1.5 years.
# - GPU performance improvement is a joint effect of smaller transistors, larger die size, and higher frequency.
# - High-end GPUs tends to first use new semiconductor technologies. Low-end GPUs may use old technologies for a few years.

# %%
data = "chip_dataset.csv"
data_df = pd.read_csv(data)

# %%
data_df.drop(columns=["Unnamed: 0"])
# Out:
#                       Product Type Release Date  Process Size (nm)  TDP (W)  \
# 0         AMD Athlon 64 3500+  CPU   2007-02-20               65.0     45.0
# 1            AMD Athlon 200GE  CPU   2018-09-06               14.0     35.0
# 2        Intel Core i5-1145G7  CPU   2020-09-02               10.0     28.0
# 3       Intel Xeon E5-2603 v2  CPU   2013-09-01               22.0     80.0
# 4     AMD Phenom II X4 980 BE  CPU   2011-05-03               45.0    125.0
# ...                       ...  ...          ...                ...      ...
# 4849      NVIDIA Quadro 3000M  GPU   2011-02-22               40.0     75.0
# 4850            Intel GMA 950  GPU   2005-06-01               90.0      7.0
# 4851   NVIDIA GeForce GT 320M  GPU   2010-03-03               40.0     23.0
# 4852   NVIDIA GeForce FX 5200  GPU   2003-03-06              150.0      NaN
# 4853   NVIDIA GeForce 9300 SE  GPU   2008-06-01               65.0      NaN
#
#       Die Size (mm^2)  Transistors (million)  Freq (MHz)  Foundry  Vendor  \
# 0                77.0                  122.0      2200.0  Unknown     AMD
# 1               192.0                 4800.0      3200.0  Unknown     AMD
# 2                 NaN                    NaN      2600.0    Intel   Intel
# 3               160.0                 1400.0      1800.0    Intel   Intel
# 4               258.0                  758.0      3700.0  Unknown     AMD
# ...               ...                    ...         ...      ...     ...
# 4849            332.0                 1950.0       450.0     TSMC  NVIDIA
# 4850              NaN                    NaN       250.0    Intel   Intel
# 4851            100.0                  486.0       500.0     TSMC  NVIDIA
# 4852             65.0                   29.0       250.0     TSMC  NVIDIA
# 4853             86.0                  210.0       540.0     TSMC  NVIDIA
#
#       FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 0             NaN          NaN          NaN
# 1             NaN          NaN          NaN
# 2             NaN          NaN          NaN
# 3             NaN          NaN          NaN
# 4             NaN          NaN          NaN
# ...           ...          ...          ...
# 4849          NaN        432.0         36.0
# 4850          NaN          NaN          NaN
# 4851          NaN         52.8          NaN
# 4852          NaN          NaN          NaN
# 4853          NaN         20.8          NaN
#
# [4854 rows x 13 columns]

# %%
data_df.value_counts()
# Out:
# Unnamed: 0  Product                                 Type  Release Date  Process Size (nm)  TDP (W)  Die Size (mm^2)  Transistors (million)  Freq (MHz)  Foundry  Vendor  FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 2194        NVIDIA GeForce MX150 GP107              GPU   2019-02-23    14.0               25.0     132.0            3300.0                 1469.0      Samsung  NVIDIA  18.38        1177.0       36.77          1
# 4006        AMD Radeon RX Vega M GL                 GPU   2018-02-01    14.0               65.0     208.0            5000.0                 931.0       GF       AMD     2588.00      2588.0       161.80         1
# 3990        AMD Radeon RX Vega 11 Mobile            GPU   2019-10-22    14.0               15.0     210.0            4940.0                 300.0       GF       AMD     3942.00      1971.0       123.20         1
# 3973        NVIDIA P106-100                         GPU   2017-06-19    16.0               120.0    200.0            4400.0                 1506.0      TSMC     NVIDIA  68.36        4375.0       136.70         1
# 3955        AMD Radeon Pro V320                     GPU   2017-06-29    14.0               230.0    495.0            12500.0                852.0       GF       AMD     16380.00     8192.0       512.00         1
#                                                                                                                                                                                                                  ..
# 3000        AMD Radeon RX 460 1024SP                GPU   2017-01-17    14.0               75.0     123.0            3000.0                 1090.0      GF       AMD     2458.00      2458.0       153.60         1
# 2998        AMD Radeon R9 Nano                      GPU   2015-08-27    28.0               175.0    596.0            8900.0                 1000.0      TSMC     AMD     8192.00      8192.0       512.00         1
# 2993        AMD Radeon RX 550                       GPU   2017-04-20    14.0               50.0     103.0            2200.0                 1100.0      GF       AMD     1211.00      1211.0       75.71          1
# 2978        NVIDIA GeForce RTX 2070                 GPU   2018-10-17    12.0               175.0    445.0            10800.0                1410.0      TSMC     NVIDIA  14930.00     7465.0       233.30         1
# 4840        NVIDIA GeForce RTX 2060 Mobile Refresh  GPU   2019-01-29    12.0               65.0     445.0            10800.0                1005.0      TSMC     NVIDIA  11980.00     5990.0       187.20         1
# Length: 428, dtype: int64

# %%
import matplotlib.pyplot as plt

x = data_df["Release Date"]
y1 = data_df["Process Size (nm)"]
y2 = data_df["Transistors (million)"]


plt.figure(figsize=(20,20))
plt.title("Process Size (nm)")
plt.plot(sorted(x.sample(10)), y1.sample(10))

# plt.plot(x,y2)

# %%
data_df_vendors = data_df["Vendor"]
data_df_vendors.unique()
# Out:
# array(['AMD', 'Intel', 'Other', 'NVIDIA', 'ATI'], dtype=object)
